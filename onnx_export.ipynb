# %%
from ultralytics import YOLO

# Load your trained YOLO model
model = YOLO(r"C:\aerial_project\runs\detect\train\weights\best.pt")

# Export to ONNX
model.export(format="onnx", opset=12)  # opset 12 is standard for ONNX CPU
# Out:
# Ultralytics YOLOv8.0.196  Python-3.9.13 torch-2.0.1+cpu CPU (Intel Core(TM) i5-8265U 1.60GHz)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'C:\aerial_project\runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 12...
# ONNX: export success  4.4s, saved as 'C:\aerial_project\runs\detect\train\weights\best.onnx' (11.7 MB)
#
# Export complete (18.7s)
# Results saved to C:\aerial_project\runs\detect\train\weights
# Predict:         yolo predict task=detect model=C:\aerial_project\runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=C:\aerial_project\runs\detect\train\weights\best.onnx imgsz=640 data=C:/aerial_project/dataset/data.yaml
# Visualize:       https://netron.app
# ============== Diagnostic Run torch.onnx.export version 2.0.1+cpu ==============
# ...

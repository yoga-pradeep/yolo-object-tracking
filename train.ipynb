# %%
import os
os.getcwd()
# Out:
# 'C:\\aerial_project\\notebooks'

# %%
import os
os.chdir(r"C:\aerial_project")
print(os.getcwd())
os.path.exists("dataset/data.yaml")
# Out:
# C:\aerial_project
# True

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="C:/aerial_project/dataset/data.yaml",
    imgsz=640,
    epochs=30,
    batch=8,
    device='cpu',    
    workers=2
)

# %%
from ultralytics import YOLO

model = YOLO(r"C:\aerial_project\runs\detect\train\weights\best.pt")

model.track(
    source=r"C:\aerial_project\test_video\test5.mp4", 
    tracker="bytetrack.yaml",     
    show=True,                  
    save=True,                  
    persist=True 

)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/301) C:\aerial_project\test_video\test5.mp4: 512x640 1 helicopter, 944.1ms
# video 1/1 (2/301) C:\aerial_project\test_video\test5.mp4: 512x640 1 helicopter, 1118.0ms
# video 1/1 (3/301) C:\aerial_project\test_video\test5.mp4: 512x640 1 helicopter, 676.7ms
# video 1/1 (4/301) C:\aerial_project\test_video\test5.mp4: 512x640 1 helicopter, 420.7ms
# ...
